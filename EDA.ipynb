# %% [markdown]
# ## About Dataset
#
#  Solar-based energy is becoming one of the most promising sources for producing power for residential, commercial, and industrial applications. Energy production based on solar photovoltaic (PV) systems has gained much attention from researchers and practitioners recently due to its desirable characteristics. However, the main difficulty in solar energy production is the volatility intermittent of photovoltaic system power generation, which is mainly due to weather conditions. For the large-scale solar farms, the power imbalance of the photovoltaic system may cause a significant loss in their economical profit. Accurate forecasting of the power output of PV systems in a short term is of great importance for daily/hourly efficient management of power grid production, delivery, and storage, as well as for decision-making on the energy market, facilitate early participation in energy auction markets and efficient resource planning.
#
#  - The data consists of 4213 rows and 21 columns

# %% [markdown]
# ##  Import Required Packages
#
# ### Importing Pandas, Numpy, Matplotlib, Seaborn and Warnings Library.

# %%
## importing all the libraries 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('spg.csv')
df.head()
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# 2                       1035.4                      0.0                  0.0
# 3                       1035.4                      0.0                  0.0
# 4                       1034.4                      0.0                  0.0
#
#    total_cloud_cover_sfc  high_cloud_cover_high_cld_lay  \
# 0                    0.0                              0
# ...

# %%
df.shape
# Out:
# (4213, 21)

# %%
## checking the null values
df.isnull().sum()
# Out:
# temperature_2_m_above_gnd            0
# relative_humidity_2_m_above_gnd      0
# mean_sea_level_pressure_MSL          0
# total_precipitation_sfc              0
# snowfall_amount_sfc                  0
# total_cloud_cover_sfc                0
# high_cloud_cover_high_cld_lay        0
# medium_cloud_cover_mid_cld_lay       0
# low_cloud_cover_low_cld_lay          0
# shortwave_radiation_backwards_sfc    0
# wind_speed_10_m_above_gnd            0
# wind_direction_10_m_above_gnd        0
# wind_speed_80_m_above_gnd            0
# wind_direction_80_m_above_gnd        0
# wind_speed_900_mb                    0
# wind_direction_900_mb                0
# wind_gust_10_m_above_gnd             0
# angle_of_incidence                   0
# zenith                               0
# azimuth                              0
# generated_power_kw                   0
# dtype: int64

# %%
## Checking the Duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                                     count         mean         std  \
# temperature_2_m_above_gnd          4213.0    15.068111    8.853677
# relative_humidity_2_m_above_gnd    4213.0    51.361025   23.525864
# mean_sea_level_pressure_MSL        4213.0  1019.337812    7.022867
# total_precipitation_sfc            4213.0     0.031759    0.170212
# snowfall_amount_sfc                4213.0     0.002808    0.038015
# total_cloud_cover_sfc              4213.0    34.056990   42.843638
# high_cloud_cover_high_cld_lay      4213.0    14.458818   30.711707
# medium_cloud_cover_mid_cld_lay     4213.0    20.023499   36.387948
# low_cloud_cover_low_cld_lay        4213.0    21.373368   38.013885
# shortwave_radiation_backwards_sfc  4213.0   387.759036  278.459293
# wind_speed_10_m_above_gnd          4213.0    16.228787    9.876948
# wind_direction_10_m_above_gnd      4213.0   195.078452  106.626782
# wind_speed_80_m_above_gnd          4213.0    18.978483   11.999960
# ...

# %% [markdown]
# ## Key Insights
# 1. Temperature
#     - Ranges from -5.35°C to 34.9°C.
#     - Mean temperature is 15.07°C, with a standard deviation of 8.85°C.
#     - The majority of the data falls between 8.39°C and 21.29°C (25th-75th percentile range).
# 2. Humidity
#     - Varies from 7% to 100%, with a mean of 51.36%.
#     - The median is 48%, suggesting a balanced spread.
# 3. Atmospheric Pressure
#     - Mean pressure is 1019.34 hPa, with a range from 997.5 hPa to 1046.8 hPa.
#     - Most values are within 1014.5 hPa to 1023.6 hPa, indicating a relatively stable atmospheric pressure.
# 4. Precipitation & Snowfall
#     Total precipitation:
#     - Mean = 0.0317 mm, max = 3.2 mm, and most values are 0 mm, suggesting very few rainy days.
#     Snowfall:
#     - Almost negligible (mean = 0.0028 mm, max = 1.68 mm), implying the location experiences little to no snowfall.
# 5. Cloud Cover
#     Total Cloud Cover
#     - Mean = 34%, but 50% of the time, it's below 8.7%, indicating frequent clear skies.
#     - High, Medium, and Low Cloud Cover:
#     - Mostly concentrated around low values (0-10%), meaning minimal cloud interference.
# 6. Solar Radiation (shortwave_radiation_backwards_sfc)
#     - Mean radiation = 387.76 W/m², max = 952.3 W/m².
#     - A high standard deviation (278.46 W/m²) indicates significant variations.
# 7. Wind Speed & Direction
#     - Wind speed at different altitudes:
#     - 10m: Mean = 5.7 m/s, max = 21.6 m/s.
#     - 80m: Mean = 18.97 m/s, max = 66.88 m/s (strong winds at higher altitudes).
#     - Wind direction: Varies widely (0° to 360°).
# 8. Solar Angles (angle_of_incidence, zenith, azimuth)
#     Angle of Incidence:
#     - Mean = 50.83°, max = 121.63°.
#     - Zenith Angle:
#     - Mean = 59.98°, max = 128.41°.
#     - Azimuth Angle:
#     - Ranges from 54.38° to 289.04°, suggesting diverse sun positions.
# 9. Generated Power (generated_power_kw)
#     - Min = 0.0006 kW, Max = 3056.79 kW.
#     - Mean = 1134.35 kW, indicating a good power generation potential.
#     - High standard deviation (937.96 kW) suggests power generation varies significantly based on conditions

# %% [markdown]
# ## Key Takeaways
# - Clear skies are common, which is ideal for solar energy generation.
# - Wind speeds at higher altitudes are strong, possibly affecting solar panel stability.
# - Power generation is highly variable, implying strong dependencies on environmental factors.
# - Temperature and solar angles will likely be crucial in predicting profitability.

# %%
## Info (datatype and different columns)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4213 entries, 0 to 4212
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   temperature_2_m_above_gnd          4213 non-null   float64
#  1   relative_humidity_2_m_above_gnd    4213 non-null   int64
#  2   mean_sea_level_pressure_MSL        4213 non-null   float64
#  3   total_precipitation_sfc            4213 non-null   float64
#  4   snowfall_amount_sfc                4213 non-null   float64
#  5   total_cloud_cover_sfc              4213 non-null   float64
#  6   high_cloud_cover_high_cld_lay      4213 non-null   int64
#  7   medium_cloud_cover_mid_cld_lay     4213 non-null   int64
#  8   low_cloud_cover_low_cld_lay        4213 non-null   int64
#  9   shortwave_radiation_backwards_sfc  4213 non-null   float64
#  10  wind_speed_10_m_above_gnd          4213 non-null   float64
# ...

# %% [markdown]
# ## Correlation
#
# Key points about using correlation analysis:
# - Understanding relationships:
#     It helps researchers understand the direction and strength of the relationship between variables, whether they move together positively, negatively,     or have no significant correlation.
# - Data exploration:
#     Correlation analysis is often used as an initial step in data analysis to identify potential areas of interest for further investigation.
# - Predictive insights:
#     By identifying strong correlations, researchers can potentially predict changes in one variable based on changes in another.
# - Feature selection:
#     In machine learning, correlation analysis can help identify redundant variables and select the most relevant features for building predictive models.

# %%
df.corr()
# Out:
#                                    temperature_2_m_above_gnd  \
# temperature_2_m_above_gnd                           1.000000
# relative_humidity_2_m_above_gnd                    -0.771704
# mean_sea_level_pressure_MSL                        -0.402240
# total_precipitation_sfc                            -0.083137
# snowfall_amount_sfc                                -0.121422
# total_cloud_cover_sfc                              -0.326641
# high_cloud_cover_high_cld_lay                      -0.019522
# medium_cloud_cover_mid_cld_lay                     -0.100980
# low_cloud_cover_low_cld_lay                        -0.381876
# shortwave_radiation_backwards_sfc                   0.665755
# wind_speed_10_m_above_gnd                          -0.172532
# wind_direction_10_m_above_gnd                       0.051393
# wind_speed_80_m_above_gnd                          -0.244869
# wind_direction_80_m_above_gnd                       0.086630
# ...

# %% [markdown]
# ### Using Heatmap to help us visualize relationships between numerical features.

# %%
plt.figure(figsize=[14,10])
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Features", fontsize=15, weight='bold')
plt.show()

# %% [markdown]
# ## Insights
#
# - Temperature vs Humidity → Negative correlation (hotter weather = lower humidity).
# - Temperature vs Cloud Cover → Cloudy conditions often mean lower temperatures. So some negative correlation is observed.
# - Shortwave Radiation vs Cloud Cover → Some negative correlation since clouds block sunlight.

# %%
## Dropping wind_gust_10_m_above_gnd,'wind_speed_80_m_above_gnd', 'wind_direction_80_m_above_gnd','wind_speed_900_mb', 'wind_direction_900_mb' columns
df.drop(columns=['wind_gust_10_m_above_gnd','wind_speed_80_m_above_gnd', 'wind_direction_80_m_above_gnd',
       'wind_speed_900_mb', 'wind_direction_900_mb'], inplace=True)

# %%
df.columns
# Out:
# Index(['temperature_2_m_above_gnd', 'relative_humidity_2_m_above_gnd',
#        'mean_sea_level_pressure_MSL', 'total_precipitation_sfc',
#        'snowfall_amount_sfc', 'total_cloud_cover_sfc',
#        'high_cloud_cover_high_cld_lay', 'medium_cloud_cover_mid_cld_lay',
#        'low_cloud_cover_low_cld_lay', 'shortwave_radiation_backwards_sfc',
#        'wind_speed_10_m_above_gnd', 'wind_direction_10_m_above_gnd',
#        'angle_of_incidence', 'zenith', 'azimuth', 'generated_power_kw'],
#       dtype='object')

# %% [markdown]
# ## Pairplot

# %%
## Performing Pairplot visualization on some selected features

selected_features = ["generated_power_kw",
    "temperature_2_m_above_gnd",
    "relative_humidity_2_m_above_gnd",
    "total_cloud_cover_sfc",
    "shortwave_radiation_backwards_sfc",
    "angle_of_incidence",
    "wind_speed_10_m_above_gnd"]

sns.pairplot(df[selected_features])
plt.show()

# %% [markdown]
# ## Insights
# - Temperature:
#     - Power generation might increase with temperature up to a point and then stabilize or decrease (due to overheating effects).
# - Humidity:
#     - There is no such strong correlation between humidity and generated power.
# - Shortwave Radiation:
#     - This directly represents the amount of sunlight received, so it should have a strong positive correlation with power output.
# - Wind Speed:
#     - If wind speeds are too high, they might indicate bad weather (like storms), reducing power generation.
#     - A weak correlation is observed.

# %% [markdown]
# ## Boxplot ---> To detect Outliers

# %%
# Assuming the dataset is loaded into `df`
fig, axs = plt.subplots(2, 3, figsize=(20, 7))

# Plot 1: Generated Power (kW)
sns.boxplot(y=df["generated_power_kw"], ax=axs[0, 0], color='r')
axs[0, 0].set_title('Generated Power (kW)')

# Plot 2: Temperature 2m Above Ground (°C)
sns.boxplot(y=df["temperature_2_m_above_gnd"], ax=axs[0, 1], color='b')
axs[0, 1].set_title('Temperature 2m Above Ground (°C)')

# Plot 3: Relative Humidity 2m Above Ground (%)
sns.boxplot(y=df['relative_humidity_2_m_above_gnd'], ax=axs[0, 2], color='g')
axs[0, 2].set_title('Relative Humidity 2m Above Ground (%)')

# Plot 4: Total Cloud Cover at Surface (%)
sns.boxplot(y=df["total_cloud_cover_sfc"], ax=axs[1, 0], color='r')
axs[1, 0].set_title('Total Cloud Cover at Surface (%)')

# Plot 5: Shortwave Radiation Backwards at Surface (W/m²)
sns.boxplot(y=df["shortwave_radiation_backwards_sfc"], ax=axs[1, 1], color='b')
axs[1, 1].set_title('Shortwave Radiation Backwards at Surface (W/m²)')

# Plot 6: Wind Speed 80m Above Ground (m/s)
sns.boxplot(y=df["wind_speed_10_m_above_gnd"], ax=axs[1, 2], color='g')
axs[1, 2].set_title('Wind Speed 10m Above Ground (m/s)')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insights
# - Wind Speed above 10m above Ground has some Outliers.

# %% [markdown]
# ## Histograms

# %%
fig, axs = plt.subplots(1, 2, figsize=[20,7])
plt.subplot(1,2,1)
sns.histplot(data=df['generated_power_kw'], bins=30, kde=True, color='g')
plt.subplot(1,2,2)
sns.histplot(data=df['temperature_2_m_above_gnd'], bins=30, kde=True, color='r')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insights
#
# - Generated Power:
#     - It resembles log-normal distribution. Peaks during daytime, zero at night.
# - Temperature:
#     - Gaussian (Normal) Distribution → Temperature typically follows a normal distribution in most climates, with most values concentrated around the average and fewer extreme cold/hot values.

# %%
fig, axs = plt.subplots(1, 2, figsize=[20,7])
plt.subplot(1,2,1)
sns.histplot(data=df['relative_humidity_2_m_above_gnd'], bins=30, kde=True, color='g')
plt.subplot(1,2,2)
sns.histplot(data=df['total_cloud_cover_sfc'], bins=30, kde=True, color='r')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insights
#
# - Humidity:
#     - A peak near low values (0-30%) suggests dry climate conditions.
#     - A small peak near high values (80-100%) suggests frequent humid conditions.
# - Cloud Cover:
#     - The histogram has a peak near 0% and another near 100%, it indicates bimodal distribution (either clear sky or overcast).
#     - If most values are clustered near low cloud cover, the solar farm likely operates in a sunny region.

# %%
fig, axs = plt.subplots(1, 2, figsize=[20,7])
plt.subplot(1,2,1)
sns.histplot(data=df['shortwave_radiation_backwards_sfc'], bins=30, kde=True, color='g')
plt.subplot(1,2,2)
sns.histplot(data=df['wind_speed_10_m_above_gnd'], bins=30, kde=True, color='r')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insights
#
# - Wind Speed:
#     - Wind speed at higher altitudes is typically more stable and follows a predictable pattern.
#     - The histogram shows a Log Normal or Weibull distribution(skewed-right), as extreme wind speeds are rare.
#     - Since the distribution has a long tail, it suggests occasional storms or high-wind events.

# %% [markdown]
# # Violinplot
#
# - A violin plot is used to visualize the distribution, density, and probability density function (PDF) of a dataset, combining aspects of a box plot and a kernel density plot.

# %%
fig, axs = plt.subplots(2, 3, figsize=[20, 7])

# Plot 1: Generated Power (kW)\
sns.violinplot(data=df['generated_power_kw'], ax=axs[0,0], color='r')
axs[0, 0].set_title('Generated Power (KW)')

# Plot 2:
sns.violinplot(df['temperature_2_m_above_gnd'], ax=axs[0,1], color='g')
axs[0, 1].set_title('Temperature')

sns.violinplot(df['relative_humidity_2_m_above_gnd'], ax=axs[0,2], color='b')
axs[0, 2].set_title('Relative Humidity')

sns.violinplot(df['total_cloud_cover_sfc'], ax=axs[1,0], color='r')
axs[1,0].set_title('Total Cloud Cover')

sns.violinplot(df['shortwave_radiation_backwards_sfc'], ax=axs[1,1], color='g')
axs[1, 1].set_title('Shortwave Radiation')

sns.violinplot(df['wind_speed_10_m_above_gnd'], ax=axs[1,2], color='b')
axs[1,2].set_title('Wind Speed')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Training

# %%
df.head()
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# 2                       1035.4                      0.0                  0.0
# 3                       1035.4                      0.0                  0.0
# 4                       1034.4                      0.0                  0.0
#
#    total_cloud_cover_sfc  high_cloud_cover_high_cld_lay  \
# 0                    0.0                              0
# ...

# %%
df.columns
# Out:
# Index(['temperature_2_m_above_gnd', 'relative_humidity_2_m_above_gnd',
#        'mean_sea_level_pressure_MSL', 'total_precipitation_sfc',
#        'snowfall_amount_sfc', 'total_cloud_cover_sfc',
#        'high_cloud_cover_high_cld_lay', 'medium_cloud_cover_mid_cld_lay',
#        'low_cloud_cover_low_cld_lay', 'shortwave_radiation_backwards_sfc',
#        'wind_speed_10_m_above_gnd', 'wind_direction_10_m_above_gnd',
#        'angle_of_incidence', 'zenith', 'azimuth', 'generated_power_kw'],
#       dtype='object')

# %%
# df['average_cloud_cover'] = np.mean([df['high_cloud_cover_high_cld_lay'], df['medium_cloud_cover_mid_cld_lay'], df['low_cloud_cover_low_cld_lay']], axis=0)

# %%
# df = df.drop(columns=['high_cloud_cover_high_cld_lay', 'medium_cloud_cover_mid_cld_lay', 'low_cloud_cover_low_cld_lay'])

# %%
df.head()
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# 2                       1035.4                      0.0                  0.0
# 3                       1035.4                      0.0                  0.0
# 4                       1034.4                      0.0                  0.0
#
#    total_cloud_cover_sfc  high_cloud_cover_high_cld_lay  \
# 0                    0.0                              0
# ...

# %%
## IQR

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)

IQR = Q3 - Q1

df_iqr = df[~((df < (Q1 - 1.5*IQR)) | (df > (Q3 + 1.5*IQR))).any(axis=1)]
df_iqr.head()
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# 2                       1035.4                      0.0                  0.0
# 3                       1035.4                      0.0                  0.0
# 4                       1034.4                      0.0                  0.0
#
#    total_cloud_cover_sfc  high_cloud_cover_high_cld_lay  \
# 0                    0.0                              0
# ...

# %% [markdown]
# ## Splitting the data in Independent and Dependent variables

# %%
X = df_iqr.drop(columns=['generated_power_kw'])
y = df_iqr['generated_power_kw']

# %%
X.head()
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# 2                       1035.4                      0.0                  0.0
# 3                       1035.4                      0.0                  0.0
# 4                       1034.4                      0.0                  0.0
#
#    total_cloud_cover_sfc  high_cloud_cover_high_cld_lay  \
# 0                    0.0                              0
# ...

# %%
y.head()
# Out:
# 0     454.10095
# 1    1411.99940
# 2    2214.84930
# 3    2527.60920
# 4    2640.20340
# Name: generated_power_kw, dtype: float64

# %%
## Train Test 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((1896, 15), (475, 15))

# %% [markdown]
# ## Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
## Importing all the ML models
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
def evaluate_model(true, predicted):
    mse=mean_squared_error(true, predicted)
    mae=mean_absolute_error(true, predicted)
    rmse=np.sqrt(mean_squared_error(true, predicted))
    r2_square=r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
## Beginning Model Training 
models = {
    "Linear Regression": LinearRegression(),
    "Support Vector Machines": SVR(),
    "K Nearest Neighbors": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest": RandomForestRegressor(),
    "AdaBoost": AdaBoostRegressor(),
    "Gradient Boosting": GradientBoostingRegressor(),
    "CatBoost": CatBoostRegressor(),
    "XGBoost": XGBRegressor()
}

model_list=[]
r2_list=[]

for i in range(len(list(models))):
    model =  list(models.values())[i]
    model.fit(X_train, y_train)

    # Make Predictions
    y_train_pred=model.predict(X_train)
    y_test_pred=model.predict(X_test)

    # Evaluate Train and Test dataset
    model_train_mae, model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)
    
    model_test_mae, model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)


    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
    
    print("Model Performance for Training set")
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_rmse))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('-------------------------------')

    print("Model Performance for Test set")
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    r2_list.append(model_test_r2)
    print('='*35)
    print('\n')
# Out:
# Linear Regression
# Model Performance for Training set
# - Root Mean Squared Error: 439.8088
# - Mean Absolute Error: 439.8088
# - R2 Score: 0.7913
# -------------------------------
# Model Performance for Test set
# - Root Mean Squared Error: 444.7415
# - Mean Absolute Error: 312.8869
# - R2 Score: 0.7905
# ...
#
#
# Support Vector Machines
# Model Performance for Training set
# - Root Mean Squared Error: 883.6112
# - Mean Absolute Error: 883.6112
# - R2 Score: 0.1577
# -------------------------------
# Model Performance for Test set
# - Root Mean Squared Error: 895.0364
# - Mean Absolute Error: 796.0925
# - R2 Score: 0.1517
# ...
#
#
# K Nearest Neighbors
# Model Performance for Training set
# - Root Mean Squared Error: 333.3890
# - Mean Absolute Error: 333.3890
# - R2 Score: 0.8801
# -------------------------------
# Model Performance for Test set
# - Root Mean Squared Error: 404.5518
# - Mean Absolute Error: 256.8746
# - R2 Score: 0.8267
# ...
#
#
# Decision Tree
# ...

# %% [markdown]
# ## Results

# %%
pd.DataFrame(list(zip(model_list, r2_list)), columns=['Model Name', 'R2_Score']).sort_values(by=['R2_Score'], ascending=False)
# Out:
#                 Model Name  R2_Score
# 7                 CatBoost  0.867672
# 4            Random Forest  0.861699
# 8                  XGBoost  0.859324
# 6        Gradient Boosting  0.842922
# 2      K Nearest Neighbors  0.826687
# 0        Linear Regression  0.790541
# 3            Decision Tree  0.767846
# 5                 AdaBoost  0.693815
# 1  Support Vector Machines  0.151670

# %% [markdown]
# ## Hyperparameter Tuning Random Forest, CatBoost and XGBoost

# %%
# catboost Xgboost,random forest

# %%
## Random Forest
RandomForestRegressor()
rf_params={'n_estimators': [100,120,140,160,180,200],
           'criterion': ["squared_error", "absolute_error", "friedman_mse"],
            'max_depth': [5, 8, 15, None, 10],
            'max_features': [5, 7, 'auto', 8]
           }

## CatBoost
CatBoostRegressor()
cb_params={'loss_function': ['RMSE','MAE','Quantile:alpha=value','LogLinQuantile:alpha=value','Poisson','MAPE'],
            
          }

# %%
## Model List for Hyperparameter Values
randomcv_models = [
                    ("RF", RandomForestRegressor(), rf_params)
                  ]

# %%
randomcv_models
# Out:
# [('RF',
#   RandomForestRegressor(),
#   {'n_estimators': [100, 120, 140, 160, 180, 200],
#    'criterion': ['squared_error', 'absolute_error', 'friedman_mse'],
#    'max_depth': [5, 8, 15, None, 10],
#    'max_features': [5, 7, 'auto', 8]})]

# %%
from sklearn.model_selection import RandomizedSearchCV

model_param = {}

for name, model, params in randomcv_models:
    random = RandomizedSearchCV(estimator = model,
                               param_distributions=params,
                               n_iter=100,
                               cv=3,
                               verbose=2,
                               n_jobs=-1)
    random.fit(X_train, y_train)
    model_param[name] = random.best_params_

for model_name in model_param:
    print(f'--------- The best aprams for {model_name} -------')
    print(model_param[model_name])
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# d:\Python\Deep Learning\Solar Energy Prediction\.venv\lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 60 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 31 fits failed with the following error:
# Traceback (most recent call last):
#   File "d:\Python\Deep Learning\Solar Energy Prediction\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Python\Deep Learning\Solar Energy Prediction\.venv\lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
# ...

# %%
models = {
            # "Random Forest": RandomForestRegressor(n_estimators= 180, max_features= 7, max_depth= 15, criterion= 'squared_error')
            "Random Forest": RandomForestRegressor(n_estimators= 160, max_features= 8, max_depth= None, criterion= 'friedman_mse')
}

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train, y_train)

    ## Make Prediction
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    ## Evaluate Train and Test Dataset
    model_train_mae, model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)
    model_test_mae, model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    print(list(models.keys())[i])

    print('Model Performance for Training data')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))
    
    print('---------------------------')

    print('Model Performance for Test data')
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))

    print('='*35)
    print('\n')
# Out:
# Random Forest
# Model Performance for Training data
# - Root Mean Squared Error: 131.2981
# - Mean Absolute Error: 76.6682
# - R2 Score: 0.9814
# ---------------------------
# Model Performance for Test data
# - Root Mean Squared Error: 359.6873
# - Mean Absolute Error: 201.3293
# - R2 Score: 0.8630
# ...

# %%
model1 = RandomForestRegressor(n_estimators= 160, max_features= 8, max_depth= None, criterion= 'friedman_mse')
model1.fit(X_train, y_train)

y_test_pred = model1.predict(X_test)

print(" R2_Score for Training Data:",r2_score(y_test, y_test_pred))
# Out:
#  R2_Score for Training Data: 0.8633531661893272

# %%
## Saving the 'scaler' in pickle format
import pickle
with open('scaler.pkl', 'wb') as file:
    pickle.dump(scaler, file)

with open('model1.pkl', 'wb') as file:
    pickle.dump(model1, file)

# %%
## Saving the cleaned data in CSV Format
# df.to_csv('Solar_Energy_Prediction.csv', index=False)
